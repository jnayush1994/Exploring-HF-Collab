# %% [markdown]
# <a href="https://colab.research.google.com/github/jnayush1994/Exploring-HF-Collab/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import login
from google.colab import userdata

# %%
hf_token = userdata.get('HF-TOKEN')

# %%
login(hf_token, add_to_git_credential=True)
